# %% [markdown]
# <a href="https://colab.research.google.com/github/DCI-alxogm/ml2023-starmath4/blob/main/Ago18-19/Tarea_18_de_agosto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([np.linspace(10,60,6)])
y=np.array([1.90,1.91,1.94,1.97,2.02,2.05])
plt.scatter(x,y)

N=len(x)
Aux2=x**2

#Calculo de b y m
m=((x*y).sum()-x.sum()*y.sum()*1/N)/((x**2).sum()-((x.sum())**2)/N)
b=(y.sum()-m*x.sum())/N

print("Pendiente: ")
print(m)

print("Ordenada al origen: ")
print(b)
# Out:
# Pendiente:
# 0.058791428571428564
# Ordenada al origen:
# -0.5561999999999987
